# %%
# Make a short EDA report (in Markdown cells within Jupyter):

# Dataset name and size

# Number of missing values per column

# Top 5 restaurants with highest rating

# Cities with most restaurants

# Simple observation (e.g., “Most high-rated restaurants are in Delhi NCR”)

# %% [markdown]
# # 🧠 EDA Report – Zomato Dataset
#
# ### 📊 Dataset Overview
# **Dataset Name:** Zomato Restaurant Data
# **File Size:** Approximately a few MBs
# **Number of Rows and Columns:** Use the code below to display it.

# %%
import pandas as pd

# %% [markdown]
# # Dataset Name

# %%
zomato_zip = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main\Zomato_Dataset\zomato.csv"

df = pd.read_csv(zomato_zip,encoding="latin1")

# %% [markdown]
# # Dataset Size

# %%
# Check dataset shape
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# # Missing Values per column

# %%
# Display the number of missing values in each column
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Top 5 restaurants with highest rating
top_restaurants = df.sort_values(by='Aggregate rating', ascending=False).head(5) # Descending order
top_restaurants[['Restaurant Name','Aggregate rating','City']]
# Out:
#                                Restaurant Name  Aggregate rating  \
# 8     Spiral - Sofitel Philippine Plaza Manila               4.9
# 10                            Silantro Fil-Mex               4.9
# 3                                         Ooma               4.9
# 9458                                Urbanologi               4.9
# 507                   Mazzaro's Italian Market               4.9
#
#                   City
# 8           Pasay City
# 10          Pasig City
# 3     Mandaluyong City
# 9458        Inner City
# 507          Tampa Bay

# %%
# Cities with most restaurants
city_counts = df['City'].value_counts().head(5)
city_counts
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: count, dtype: int64
