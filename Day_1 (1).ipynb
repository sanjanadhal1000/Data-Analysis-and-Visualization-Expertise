# %%
import os, sys
print("✅ Python version:", sys.version)
print("✅ Current directory:", os.getcwd())
print("✅ Can access C drive:", os.path.exists("C:\\"))
# Out:
# ✅ Python version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# ✅ Current directory: C:\Users\hp
# ✅ Can access C drive: True

# %%
import zipfile, os

zip_path = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\5-Days-Live-EDA-and-Feature-Engineering-main.zip"
extract_to = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("✅ Extraction done at:", extract_to)
# Out:
# ✅ Extraction done at: C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files

# %%
os.listdir(extract_to)
# Out:
# ['5-Days-Live-EDA-and-Feature-Engineering-main']

# %%
import os, glob
import pandas as pd

# Path to your extracted folder
data_folder = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files"

# Find all CSV files
csv_files = glob.glob(data_folder + "/**/*.csv", recursive=True)
csv_files
# Out:
# []

# %%
import os

root_path = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main"

for root, dirs, files in os.walk(root_path):
    print(f"\n📁 Folder: {root}")
    for f in files:
        print("   -", f)
# Out:
# 📁 Folder: C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main
#    - 1-EDA And Feature Engineering.ipynb
#    - 2- BlackFriday EDA And Feature Engineering.ipynb
#    - LICENSE
#    - README.md
#    - Zomatodataset.zip
#
# 📁 Folder: C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main\Flight Prediction
#    - Data_Train.xlsx
#    - FlightPrediction.ipynb
#    - Test_set.xlsx

# %%
## Zomato Exploratory Data Analysis

# %%
import zipfile, os

zomato_zip = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main\Zomatodataset.zip"
extract_to = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main\Zomato_Dataset"

with zipfile.ZipFile(zomato_zip, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"Zomato Dataset extracted to: {extract_to}")
print(os.listdir(extract_to))
# Out:
# Zomato Dataset extracted to: C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main\Zomato_Dataset
# ['Country-Code.xlsx', 'file1.json', 'file2.json', 'file3.json', 'file4.json', 'file5.json', 'Untitled.ipynb', 'zomato.csv']

# %%
import pandas as pd

# Direct path to the CSV file (after extracting Zomatodataset.zip)
zomato_file = r"C:\Users\hp\OneDrive\Documents\Data Analysis and Visualization Expertise\Extracted_Files\5-Days-Live-EDA-and-Feature-Engineering-main\Zomato_Dataset\zomato.csv"

# Read the CSV
# Load the dataset using 'latin1' encoding to avoid Unicode errors.
df = pd.read_csv(zomato_file, encoding='latin1')

# Display first 5 rows
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape      # number of rows and columns
# Out:
# (9551, 21)

# %%
df.columns    # list of column names
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()     # overview of datatypes and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.head(3)     # preview first few rows
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
df.describe(include="all") # Display quick summary statistics for all columns
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                  Address         Locality            Locality Verbose  \
# count               9551             9551                        9551
# ...

# %%
df.describe() # Display quick summary statistics for numerical columns
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
# Data Selection

# %%
df['Rating color'] # column
# Out:
# 0       Dark Green
# 1       Dark Green
# 2            Green
# 3       Dark Green
# 4       Dark Green
#            ...
# 9546         Green
# 9547         Green
# 9548        Yellow
# 9549         Green
# 9550         Green
# Name: Rating color, Length: 9551, dtype: object

# %%
df[['Restaurant ID','Restaurant Name']]
# Out:
#       Restaurant ID           Restaurant Name
# 0           6317637          Le Petit Souffle
# 1           6304287          Izakaya Kikufuji
# 2           6300002    Heat - Edsa Shangri-La
# 3           6318506                      Ooma
# 4           6314302               Sambo Kojin
# ...             ...                       ...
# 9546        5915730              NamlÛ± Gurme
# 9547        5908749             Ceviz AÛôacÛ±
# 9548        5915807                     Huqqa
# 9549        5916112              Aôôk Kahve
# 9550        5927402  Walter's Coffee Roastery
#
# [9551 rows x 2 columns]

# %%
df.iloc[0:5, 0:3]
# Out:
#    Restaurant ID         Restaurant Name  Country Code
# 0        6317637        Le Petit Souffle           162
# 1        6304287        Izakaya Kikufuji           162
# 2        6300002  Heat - Edsa Shangri-La           162
# 3        6318506                    Ooma           162
# 4        6314302             Sambo Kojin           162

# %%
df.loc[df['Aggregate rating'] > 4.0]
# Out:
#       Restaurant ID         Restaurant Name  Country Code              City  \
# 0           6317637        Le Petit Souffle           162       Makati City
# 1           6304287        Izakaya Kikufuji           162       Makati City
# 2           6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                    Ooma           162  Mandaluyong City
# 4           6314302             Sambo Kojin           162  Mandaluyong City
# ...             ...                     ...           ...               ...
# 9543        5916085            Dem Karakí_y           208         ÛÁstanbul
# 9544        5915547   Karakí_y Gí_llí_oÛôlu           208         ÛÁstanbul
# 9545        5915054                Baltazar           208         ÛÁstanbul
# 9546        5915730            NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749           Ceviz AÛôacÛ±           208         ÛÁstanbul
#
# ...

# %%
# Missing Values

# %%
df.isnull().sum() # Check the total no. of missing values in each column.
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna(inplace=False)
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# Replace all NaN (missing) values with 0
df.fillna(0, inplace=False)
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# Fill missing values for a specific column

# If there is a numeric column, fill missing values with mean
# df['Price range'].fillna(df['Price range'].mean(), inplace = True)

# If there’s a text column like 'city', fill blanks with 'Unknown'
# df['city'].fillna('Unknown', inplace=True)

# %%
# Forward-fill or Backward-fill Missing data

# # Forward-fill: copies the previous value
# df.fillna(method="ffill",inplace=True)

# # Backward fill: copies the next value
# df.fillna(method="bfill",inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Sorting and Basic Aggregation

# %%
df.sort_values(by='Aggregate rating', ascending=False).head(10)
# Out:
#       Restaurant ID                             Restaurant Name  Country Code  \
# 8           6300010    Spiral - Sofitel Philippine Plaza Manila           162
# 10          6309903                            Silantro Fil-Mex           162
# 3           6318506                                        Ooma           162
# 9458       18339373                                  Urbanologi           189
# 507        17095098                    Mazzaro's Italian Market           216
# 509        17095236  Mr. Dunderbak's Biergarten and Marketplatz           216
# 429        17145495                               Marukame Udon           216
# 428        17142792                           Mama's Fish House           216
# 580         5703500                                Punjab Grill           214
# 589        18269368                     AB's Absolute Barbecues           214
#
#                   City                                            Address  \
# ...

# %%
df['Price range'].mean()
# Out:
# np.float64(1.804837189823055)

# %%
df.groupby('City')['Aggregate rating'].mean()
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ÛÁstanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64
